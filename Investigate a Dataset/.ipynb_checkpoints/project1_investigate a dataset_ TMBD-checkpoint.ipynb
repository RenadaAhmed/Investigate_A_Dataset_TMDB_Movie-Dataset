# %% [markdown]
# # Project: Investigate a Dataset ( Database_TMDb_movie_data )
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#EDA">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# A Kaggle dataset consisting This data set contains information about 10,000 movies collected from The Movie Database (TMDb),
# including user ratings and revenue.
# The final two columns ending with “_adj” show the budget and revenue of the associated movie in terms of 2010 dollars,
# accounting for inflation over time.
#
# ### Questions:
#
#   *  Which genres are most popular from year to year ?
#   *  Which Genre Has The Highest Release Of Movies ?
#   *  Which movie has the highest profit ?
#   * Which movie genre has the highest Budget ?
#   * Is a Movie's rating gets Higher with less runtime ?
#   * Which year has the highest release of movies?
#   * Most Frequent Actor ?
#   * Top 10 Production Companies With Higher Number Of Release ?
#   * movie Rating dependency on profit?
#   * What kinds of properties are associated with movies that have high revenues ?

# %% [markdown]
# Import needed libraries and load your Data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %%
df_tmbd = pd.read_csv("tmdb-movies.csv")
df_tmbd.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
df_tmbd.shape
# Out:
# (10866, 21)

# %%
df_tmbd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
df_tmbd.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df_tmbd.duplicated().sum()
# Out:
# 1

# %%
df_tmbd.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# - we notice that `release_date` is string so we need to fix the data type to date
# - There are some irrelevent columns & many missing values (Null)
# - one duplicate value need to be droped.
# - some Movie `budget` is zero which will only cause disturbance to the data as the are irrelevant

# %% [markdown]
# #### Data Cleaning

# %%
# drop unwanted columns 
df_tmbd.drop(['id','imdb_id','homepage','tagline','keywords','overview','budget_adj','revenue_adj'],axis=1 ,inplace=True)
df_tmbd.head(3)
# Out:
#    popularity     budget     revenue      original_title  \
# 0   32.985763  150000000  1513528810      Jurassic World
# 1   28.419936  150000000   378436354  Mad Max: Fury Road
# 2   13.112507  110000000   295238201           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015

# %%
# Drop duplicates
df_tmbd.drop_duplicates(inplace=True)

# %% [markdown]
# Now lets remove all Movies with Zero Budget

# %%
df_nobud = df_tmbd.query('budget == 0')
df_tmbd.drop(df_nobud.index,inplace=True)

# %%
df_tmbd.shape
# Out:
# (5169, 13)

# %% [markdown]
# fixing `release_date` data type

# %%
df_tmbd['release_date'] = pd.to_datetime(df_tmbd['release_date'], infer_datetime_format=True)
#df_tmbd.release_year=df_tmbd.release_year.astype(str)

# %%
# Drop null values 

df_tmbd.dropna(inplace=True)
df_tmbd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5021 entries, 0 to 10865
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            5021 non-null   float64
#  1   budget                5021 non-null   int64
#  2   revenue               5021 non-null   int64
#  3   original_title        5021 non-null   object
#  4   cast                  5021 non-null   object
#  5   director              5021 non-null   object
#  6   runtime               5021 non-null   int64
#  7   genres                5021 non-null   object
#  8   production_companies  5021 non-null   object
#  9   release_date          5021 non-null   datetime64[ns]
#  10  vote_count            5021 non-null   int64
#  11  vote_average          5021 non-null   float64
#  12  release_year          5021 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(5)
# memory usage: 549.2+ KB

# %%
df_tmbd.shape
# Out:
# (5021, 13)

# %%
#make a copy movies data and split the column of genres into rows for Questions
df = df_tmbd.copy()   # make cpoy of data 


genre = df['genres'].str.split('|')  

  # put into series to avoid getting nan values
genre_series = genre.apply(pd.Series, 1)
genre_series_clean = genre_series.stack()
genre_series_clean.index = genre_series_clean.index.droplevel(-1)
genredf = pd.DataFrame(genre_series_clean)

# Delete the `Ticket` column from your DataFrame
del df['genres']
df = df.join(genredf)
df.rename(columns={0:'genres'},inplace=True)
df.head()
# Out:
#    popularity     budget     revenue      original_title  \
# 0   32.985763  150000000  1513528810      Jurassic World
# 0   32.985763  150000000  1513528810      Jurassic World
# 0   32.985763  150000000  1513528810      Jurassic World
# 0   32.985763  150000000  1513528810      Jurassic World
# 1   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#    runtime                               production_companies release_date  \
# 0      124  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 0      124  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 0      124  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 0      124  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1      120  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
#
#    vote_count  vote_average  release_year           genres
# 0        5562           6.5          2015           Action
# 0        5562           6.5          2015        Adventure
# 0        5562           6.5          2015  Science Fiction
# 0        5562           6.5          2015         Thriller
# 1        6185           7.1          2015           Action

# %%
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 popularity
# 1 budget
# 2 revenue
# 3 original_title
# 4 cast
# 5 director
# 6 runtime
# 7 production_companies
# 8 release_date
# 9 vote_count
# 10 vote_average
# 11 release_year
# 12 genres

# %% [markdown]
# <a id='EDA'></a>
# ## Exploratory Data Analysis
#
#
# ###  Question 1 ( Which genres are most popular from year to year ?)

# %%
 
df_gen = df.copy()

    # turn years to decads 
df_gen.release_year = df_gen.release_year.apply(lambda x:(x //10)*10)
df_gen_edit = pd.DataFrame(df_gen.groupby(['release_year','genres'],as_index=False).popularity.sum())  
df_gen_edit.head()
# Out:
#    release_year     genres  popularity
# 0          1960     Action   28.438223
# 1          1960  Adventure   37.951481
# 2          1960  Animation    6.410273
# 3          1960     Comedy   23.499731
# 4          1960      Crime   11.175777

# %% [markdown]
# Rows with multiple values in genres column are splitted into multiple rows

# %%
df_gen_clean = pd.DataFrame(df_gen.groupby(['release_year','genres']).popularity.sum())
   #dataframe for popularity of each genre over decades
df_gen_clean.head(20)
# Out:
#                               popularity
# release_year genres
# 1960         Action            28.438223
#              Adventure         37.951481
#              Animation          6.410273
#              Comedy            23.499731
#              Crime             11.175777
#              Drama             39.504398
#              Family            12.577776
#              Fantasy            3.679572
#              Foreign            0.235542
#              History            7.894969
#              Horror             7.390342
#              Music              7.359543
#              Mystery            9.102123
#              Romance           14.675422
#              Science Fiction    6.802364
#              Thriller          25.657690
#              War                9.210080
#              Western            6.453968
# 1970         Action            49.559404
#              Adventure         46.242313

# %%
df_gen_clean.unstack().plot(figsize=(15,15),linewidth=2.5);   
plt.title("Most Popular Genre Over Year To Year",fontsize=12);

# %%
df_gen_clean.unstack().plot(kind='bar',figsize=(20,15),linewidth=3.5);   
plt.title("Most Popular Genre Over Year To Year",fontsize=12);

# %%
fig, ax = plt.subplots(3,2,figsize = (23,15))
ax[2][1].set_visible(False)

df_gen_clean.query("genres == 'Drama'").plot(kind='barh',label ="Drama",ax = ax[0][0]);
df_gen_clean.query("genres == 'Action'").plot(kind='barh',label ="Action",ax = ax[0][1]);
df_gen_clean.query("genres == 'Adventure'").plot(kind='barh',label ="Adventure",ax = ax[1][0]);
df_gen_clean.query("genres == 'Thriller'").plot(kind='barh',label ="Thriller",ax = ax[1][1]);
df_gen_clean.query("genres == 'Comedy'").plot(kind='barh',label ="Comedy",ax = ax[2][0]);



fig.suptitle('Genre Popularity Over Year To Year',fontsize = 17);

# %% [markdown]
# - Drama has the highest popularity among genres over time but fell befind alittle in 80's
# - top popular genres:
#     * Drama
#     * Action
#     * Thriller
#     * Adventure
#     * Comedy

# %% [markdown]
# ###  Question 2 ( Which Genre Has The Highest Release Of Movies ?)

# %%
df_gen['genres'].value_counts()
# Out:
# Drama              2258
# Comedy             1692
# Thriller           1605
# Action             1389
# Adventure           892
# Romance             843
# Crime               812
# Horror              738
# Science Fiction     688
# Family              507
# Fantasy             496
# Mystery             436
# Animation           255
# History             178
# Music               160
# War                 153
# Western              74
# Documentary          43
# Foreign              27
# TV Movie              9
# Name: genres, dtype: int64

# %%
df_gen.genres.value_counts().sort_values().plot(kind = 'barh', figsize=(9,9),color ='y')   
                              #sort genre values
# Out:
# <AxesSubplot:>

# %% [markdown]
# `Drama` has the highest release of Movies with 2285 movie

# %% [markdown]
# ###  Question 3  (Which movie has the highest profit ?)

# %%
df_pro = df_tmbd.copy()   # make copy of original data

# create profit column and adding it to data
df_pro['profit'] = df_pro['revenue'] - df_pro['budget']
df_pro = df_pro.set_index('profit', append=True).sort_index(level=1,ascending=False).reset_index(level=1)
df_pro.head()
# Out:
#           profit  popularity     budget     revenue  \
# 1386  2544505847    9.432768  237000000  2781505847
# 3     1868178225   11.173104  200000000  2068178225
# 5231  1645034188    4.355219  200000000  1845034188
# 0     1363528810   32.985763  150000000  1513528810
# 4     1316249360    9.335014  190000000  1506249360
#
#                     original_title  \
# 1386                        Avatar
# 3     Star Wars: The Force Awakens
# 5231                       Titanic
# 0                   Jurassic World
# 4                        Furious 7
#
#                                                    cast         director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...    James Cameron
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...      J.J. Abrams
# 5231  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...    James Cameron
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 4     Vin Diesel|Paul Walker|Jason Statham|Michelle ...        James Wan
#
#       runtime                                     genres  \
# 1386      162   Action|Adventure|Fantasy|Science Fiction
# 3         136   Action|Adventure|Science Fiction|Fantasy
# 5231      194                     Drama|Romance|Thriller
# 0         124  Action|Adventure|Science Fiction|Thriller
# 4         137                      Action|Crime|Thriller
#
#                                    production_companies release_date  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...   2009-12-10
# 3             Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15
# 5231  Paramount Pictures|Twentieth Century Fox Film ...   1997-11-18
# 0     Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 4     Universal Pictures|Original Film|Media Rights ...   2015-04-01
#
#       vote_count  vote_average  release_year
# 1386        8458           7.1          2009
# 3           5292           7.5          2015
# 5231        4654           7.3          1997
# 0           5562           6.5          2015
# 4           2947           7.3          2015

# %%
  # get top 10 profitable Movies
df_pro_10 = df_pro.head(10);

ax =  sns.barplot(x="profit", y="original_title",data=df_pro_10, palette="Set2");
ax.set_title("top 10 profitable Movies");

# %% [markdown]
# `Avatar` is the most profitable Movie followed by `star wars` & `Titanic`

# %% [markdown]
# ###  Question 4  (Which movie genre has the highest Budget ?)

# %%
print(df.groupby('genres')['budget'].mean())  # group by average budget for each genre 

df.groupby('genres')['budget'].mean().plot(kind='bar', figsize =(12,12),color ="#8B008B");
plt.title("Movie Genres highst budget");
plt.xlabel(" Movie genre");
plt.ylabel("Budget");
plt.grid(True)

plt.show();
# Out:
# genres
# Action             4.740669e+07
# Adventure          6.177278e+07
# Animation          6.332642e+07
# Comedy             2.966531e+07
# Crime              2.934567e+07
# Documentary        6.229217e+06
# Drama              2.489271e+07
# Family             5.638677e+07
# Fantasy            6.014405e+07
# Foreign            8.842415e+06
# History            3.451502e+07
# Horror             1.371246e+07
# Music              2.386163e+07
# Mystery            2.979933e+07
# Romance            2.533576e+07
# Science Fiction    4.456227e+07
# TV Movie           4.966667e+06
# Thriller           3.099938e+07
# War                3.660398e+07
# Western            4.230713e+07
# Name: budget, dtype: float64

# %% [markdown]
# * from the plot it appers that `Animation ` has the highest budget
# - * 1-Animation
#   * 2-Adventure
#   * 3-Fantasy
#   * 4-Family
#   * 5-Action
#   * 6-Science fiction

# %% [markdown]
# ###  Question 5  (Is a Movie's rating gets Higher with less runtime ?)

# %%
# take a look at runtime & rating distribation
print( "Average runtime :  " ,df_tmbd['runtime'].mean())     # average runtime

df_tmbd['runtime'].hist();
# Out:
# Average runtime :   107.52320254929298

# %% [markdown]
# right Skewed

# %%
df_tmbd['vote_average'].hist();

# %% [markdown]
# Left Skewed

# %%
fig, ax = plt.subplots(figsize = (10.5,4.55))

fig.suptitle("Rating Vs Runtime",fontsize=15);
sns.regplot(x=df_tmbd['vote_average'], y=df_tmbd['runtime'], color="#CD5C5C");

sns.axes_style("whitegrid");

# %% [markdown]
# There ia a positive correlation between `vote_average` & `Runtime` but its relatively weak
#
#   so we can not determine that runtime affect rating of a movie

# %% [markdown]
# ###  Question 6  (Which year has the highest release of movies? )

# %%
y1 = df_tmbd.groupby('release_year').count()['original_title'].sort_values(ascending=False)
print(y1.head(6))                # higher number of releases in year 
     # group by number of movies released every year

df_tmbd.groupby('release_year').count()['original_title'].plot(figsize=(10,6),xticks = np.arange(1960,2016,4));

plt.grid(True);
plt.title("Number of realeases over years");
plt.ylabel("Number of realeases");
plt.xticks(rotation=45);

plt.show();
# Out:
# release_year
# 2011    264
# 2013    261
# 2009    239
# 2010    233
# 2014    231
# 2012    228
# Name: original_title, dtype: int64

# %% [markdown]
# - the highset number of released movies is in year <b>2011<b/>
# - also the movies has increased over time specially between   <b>2007 & 2014 <b/>
#     - but droped alittle by year <b>2009<b/> compaared to other years in this period

# %% [markdown]
# ###  Question 7   (Most Frequent Actor ?)

# %%
# split column cast to rows to remove '|'
df_cast = pd.DataFrame(data=df_tmbd.cast.str.split('|').tolist(),index=[df_tmbd.original_title]).stack().reset_index([0])
df_cast.rename(mapper={0:'actor'},axis=1,inplace=True)
df_cast.head(10)
# Out:
#        original_title                actor
# 0      Jurassic World          Chris Pratt
# 1      Jurassic World  Bryce Dallas Howard
# 2      Jurassic World          Irrfan Khan
# 3      Jurassic World    Vincent D'Onofrio
# 4      Jurassic World        Nick Robinson
# 0  Mad Max: Fury Road            Tom Hardy
# 1  Mad Max: Fury Road      Charlize Theron
# 2  Mad Max: Fury Road     Hugh Keays-Byrne
# 3  Mad Max: Fury Road       Nicholas Hoult
# 4  Mad Max: Fury Road          Josh Helman

# %%
  # data frame of number of movies actors appeared in 
c1 =pd.DataFrame(df_cast.groupby('actor', as_index =False).original_title.count())
c1.rename(mapper={'original_title':'number_of_movies'},axis=1,inplace=True)  # rename column
c1.sort_values(by ='number_of_movies',ascending=False,inplace =True)

print(c1.head())
# Out:
#                   actor  number_of_movies
# 7340     Robert De Niro                58
# 1174       Bruce Willis                57
# 7706  Samuel L. Jackson                54
# 6509       Nicolas Cage                53
# 5843         Matt Damon                38

# %%
labels = c1.actor.iloc[:15]    #select top 15 common actor
sizes = c1.number_of_movies.iloc[:15]

fig, ax = plt.subplots(figsize=(10,10))
ax.pie(sizes, labels=labels,\
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend()
  
    
plt.title('Most frequent Actor')
plt.axis('equal')

plt.show()

# %% [markdown]
#  <b>Robert De Niro<b/>   is the most frequent actor who played in many movies
#
#  - followed by:
#    * Bruce Willis
#    * Samuel L. Jackson
#    * Nicolas Cage

# %% [markdown]
# ###  Question 8  (Top 10 Production Companies With Higher Number Of Release ?)

# %%
data_product = df_tmbd['production_companies'].str.cat(sep = '|')  
                                                               # seperate 'production_companies' into multiple rows 
data = pd.Series(data_product.split('|'))
df_prod = data.value_counts(ascending=False)
df_prod
# Out:
# Universal Pictures                        360
# Warner Bros.                              357
# Paramount Pictures                        305
# Twentieth Century Fox Film Corporation    213
# Columbia Pictures                         204
#                                          ...
# Entertainment Films                         1
# Caviar Films                                1
# Warner Home Video                           1
# IM Filmproduktion                           1
# Andrew Lauren Productions (ALP)             1
# Length: 4487, dtype: int64

# %%
df_prod.iloc[:10].plot(kind='barh',figsize=(11.5,7),color='magenta');

plt.grid(True);
plt.title("Production Companies Vs Number Of Movies");
plt.ylabel("Number of Movies");
plt.xticks(rotation=90);

plt.show();

# %% [markdown]
# <b> Universal Pictures  </b> released a huge number of movies 360 in 1960 to 2015 according to data

# %% [markdown]
# ###  Question 9  (movie Rating dependency on profit?)

# %%
df_pro['vote_average'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Left Skewed but close to normal distribuation

# %%
df_pro['popularity'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
#  Right Skewed
#
#  * Due to the distribuation it is better to use `vote_Average ` than using `popularity` to avoid trouble with this right skewed and also get rating on a specified scale from 1 to 10

# %%
 fig, axes = plt.subplots(figsize = (10,7))

fig.suptitle("Rating vs profit",fontsize=15)
sns.regplot(x=df_pro['profit'], y=df_pro['vote_average']);

print('correlation = ',df_pro.corr().loc['vote_average','profit'])
# Out:
# correlation =  0.26768798995590365

# %% [markdown]
# <b>Rating & profit : </b>
#
# has weak positive correlation (0.26) so it is not necessary that higher rating gets higher profit

# %% [markdown]
# ###  Question 10  (What kinds of properties are associated with movies that have high revenues ?)

# %%
df_rev = df_tmbd.set_index('revenue', append=True).sort_index(level=1,ascending=False).reset_index(level=1)
df_rev.head(3)
# Out:
#          revenue  popularity     budget                original_title  \
# 1386  2781505847    9.432768  237000000                        Avatar
# 3     2068178225   11.173104  200000000  Star Wars: The Force Awakens
# 5231  1845034188    4.355219  200000000                       Titanic
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...    J.J. Abrams
# 5231  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...  James Cameron
#
#       runtime                                    genres  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction
# 3         136  Action|Adventure|Science Fiction|Fantasy
# 5231      194                    Drama|Romance|Thriller
#
#                                    production_companies release_date  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...   2009-12-10
# 3             Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15
# 5231  Paramount Pictures|Twentieth Century Fox Film ...   1997-11-18
#
#       vote_count  vote_average  release_year
# 1386        8458           7.1          2009
# 3           5292           7.5          2015
# 5231        4654           7.3          1997

# %%
plt.figure(figsize=(10,10))    # correlation matrix
sns.heatmap(df_rev.corr(method='pearson', min_periods=1),annot=True ,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
X = df_rev.drop(['vote_count','revenue'] , axis=1)
y = df_rev['revenue']
X.corrwith(y).plot(kind='bar', grid=False, figsize=(7, 8), title="Correlation with the Revenue");

# %%
fig, axes = plt.subplots(2,2,figsize = (11,11))

fig.suptitle("Revenus relation with other properities",fontsize=15);
sns.regplot(x=df_rev['revenue'], y=df_rev['budget'],ax=axes[0][0]);
sns.regplot(x=df_rev['revenue'], y=df_rev['popularity'],ax=axes[0][1]);
sns.regplot(x=df_rev['revenue'], y=df_rev['vote_average'],ax=axes[1][0]);
sns.regplot(x=df_rev['revenue'], y=df_rev['runtime'],ax=axes[1][1]);

# %% [markdown]
# * <b>Plot 1 (Revenue vs budegt) :</b>
#
#     has strong positive correlation (0.7) so there may be a possibility that the more investement are made you can get more revenues
#
# * <b>Plot 2 (Revenue vs popularity) :</b>
#
#    has strong positive correlation (0.64) in some cases that popularity may help increase revenues
#
# * <b>Plot 3 (Revenue vs vote_average) :</b>
#
#    has a very weak positive correlation (0.25) it proves there is hardly any relation with revenue
#
# * <b>Plot 4 (Revenue vs runtime) :</b>
#
#    has a very weak positive correlation (0.23) it proves there is hardly any relation with revenue

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# * Drama is the most popular genre, following by action , popularity grows over time.
# * Drama has the highest release of Movies with 2285 movie , Comedy (1692).
# * Avatar is the most profitable Movie followed by star wars & Titanic.
# * Animation has the highest budget , then Adventure & fantasy.
# * we can not determine that runtime affect rating of a movie (weak relation).
# * the highset number of released movies is in year 2011 ,but droped alittle by year 2009 .
# * Robert De Niro is the most frequent actor who played in many movies.
# * Universal Pictures released a huge number of movies 360 in 1960 to 2015 according to data.
# * it is not necessary that higher rating gets higher profit.
# * a possibility that the more investement are made you can get more revenues
# * popularity may help increase revenues
# * no relayion between rating and runtime with revenue.
